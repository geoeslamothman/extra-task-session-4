# %%
x = input('nmbers from 1 to 4')
mylist=[x]
print (mylist)
# Out:
# nmbers from 1 to 4 1,2,3,4
# ['1,2,3,4']

# %%
information ={
    "name" : "islam",
    "age" : 39,
    "grade" : 92
}
print (information)
# Out:
# {'name': 'islam', 'age': 39, 'grade': 92}

# %%
product = {"name" : "laptop",
           "price" : 10000,
            "quanyity" : 1}
print(product)
product ["price"] =10
print (product)
# Out:
# {'name': 'laptop', 'price': 10000, 'quanyity': 1}
# {'name': 'laptop', 'price': 10, 'quanyity': 1}

# %%
listname = ['islam','othman','mostaf']
print (listname)
for i in listname:
    print (i)
# Out:
# ['islam', 'othman', 'mostaf']
# islam
# othman
# mostaf

# %%
embloyee = {"name" : "eslam",
            "skills" : list (("clever" , "smart ", 'formal')),
            "ID" : tuple ((10,15,20))
           }
print(embloyee)
new_skill = "man"
embloyee["skills"].append(new_skill)
print (embloyee)
# Out:
# {'name': 'eslam', 'skills': ['clever', 'smart ', 'formal'], 'ID': (10, 15, 20)}
# {'name': 'eslam', 'skills': ['clever', 'smart ', 'formal', 'man'], 'ID': (10, 15, 20)}
